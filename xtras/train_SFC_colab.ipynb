# %% [markdown]
# # BNN-PYNQ SFC Training and Exporting notebook
#
# ### -> Please, run me in Google Colab.
#
# ## Step 1: Collect compatible (old) libraries and install them on Python2.

# %%
# BNN SFC MNIST Train notebook
# by Franco Caspe
# Run it in Google Colab!

#Step 1: Collect compatible libraries.
######################################

#First downgrade numpy, then install everything.
# !pip2 install numpy==1.15.4

#Theano v0.8
# !git clone https://github.com/Theano/Theano
# %cd Theano
# !git checkout dac4da86a544dc69a6b848a1ea2f0e2e29c8d20b
# !pip2 install .
# %cd ..

#pylearn2
# !git clone https://github.com/lisa-lab/pylearn2
# %cd pylearn2
# !git checkout fe9beee9b922c97bd8e5dd2ac023e1def229da31
# !python2 setup.py develop
# %cd ..

#Set pylearn2 as it wants to be set . . .
import sys,os
os.environ['PYLEARN2_VIEWER_COMMAND'] = 'eog --new-instance'
os.environ['PYLEARN2_DATA_PATH'] = '/content/pylearn2/pylearn2/datasets'
os.environ['PYTHONPATH'] = '/content/pylearn2'

#And download and uncompress MNIST character set where pylearn can see it
# !mkdir /content/pylearn2/pylearn2/datasets/mnist
# %cd /content/pylearn2/pylearn2/datasets/mnist
# !wget http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
#!gunzip train-images-idx3-ubyte.gz
# !wget http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
#!gunzip train-labels-idx1-ubyte.gz
# !wget http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
#!gunzip t10k-images-idx3-ubyte.gz
# !wget http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# !gunzip *
# %cd -

#Downgrade lasagne
# !git clone https://github.com/Lasagne/Lasagne
# %cd Lasagne
# !git checkout 6a559dd54e0cc4930c9b29319fe45350d1a651e6
# !pip2 install .
# %cd ..

#Install old PyTables version
# !git clone https://github.com/PyTables/PyTables/
# %cd PyTables
# !git checkout 73221baf85afda517bc0646f448ffb3f8e51dd81
# !pip2 install .
# %cd ..
# Out:
# Cloning into 'BNN-PYNQ'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 4889 (delta 4), reused 3 (delta 1), pack-reused 4878
# Receiving objects: 100% (4889/4889), 186.11 MiB | 29.49 MiB/s, done.
# Resolving deltas: 100% (840/840), done.
# Checking out files: 100% (1844/1844), done.
# Collecting numpy==1.15.4
#   Downloading https://files.pythonhosted.org/packages/de/37/fe7db552f4507f379d81dcb78e58e05030a8941757b1f664517d581b5553/numpy-1.15.4-cp27-cp27mu-manylinux1_x86_64.whl (13.8MB)
#      |████████████████████████████████| 13.8MB 306kB/s
# ERROR: tensorflow 1.15.0 has requirement numpy<2.0,>=1.16.0, but you'll have numpy 1.15.4 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 1.15.0 which is incompatible.
# ERROR: fastai 0.7.0 has requirement torch<0.4, but you'll have torch 1.4.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: numpy
#   Found existing installation: numpy 1.16.4
#     Uninstalling numpy-1.16.4:
#       Successfully uninstalled numpy-1.16.4
# Successfully installed numpy-1.15.4
# Cloning into 'Theano'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 165754 (delta 14), reused 22 (delta 9), pack-reused 165711
# Receiving objects: 100% (165754/165754), 66.46 MiB | 28.04 MiB/s, done.
# Resolving deltas: 100% (132017/132017), done.
# /content/Theano
# Note: checking out 'dac4da86a544dc69a6b848a1ea2f0e2e29c8d20b'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at dac4da86a Fix docgen as now warning are treated as error
# Processing /content/Theano
# Requirement already satisfied: numpy>=1.7.1 in /usr/local/lib/python2.7/dist-packages (from Theano==0.8.0.dev0) (1.15.4)
# Requirement already satisfied: scipy>=0.11 in /usr/local/lib/python2.7/dist-packages (from Theano==0.8.0.dev0) (1.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python2.7/dist-packages (from Theano==0.8.0.dev0) (1.12.0)
# Building wheels for collected packages: Theano
#   Building wheel for Theano (setup.py) ... done
#   Created wheel for Theano: filename=Theano-0.8.0.dev0-cp27-none-any.whl size=2664981 sha256=a1152892d6ed8bba80c436c96fb92c56ae2408990d100104d7da1ece61d0e137
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gv0cmn/wheels/28/65/cd/c63b11989d859e5858dbfa22b1e97ae360b3ed893894f240e9
# Successfully built Theano
# ERROR: pymc3 3.6 has requirement theano>=1.0.0, but you'll have theano 0.8.0.dev0 which is incompatible.
# Installing collected packages: Theano
#   Found existing installation: Theano 1.0.4
#     Uninstalling Theano-1.0.4:
#       Successfully uninstalled Theano-1.0.4
# Successfully installed Theano-0.8.0.dev0
# /content
# Cloning into 'pylearn2'...
# remote: Enumerating objects: 107383, done.
# remote: Total 107383 (delta 0), reused 0 (delta 0), pack-reused 107383
# Receiving objects: 100% (107383/107383), 25.42 MiB | 21.46 MiB/s, done.
# Resolving deltas: 100% (82337/82337), done.
# /content/pylearn2
# Note: checking out 'fe9beee9b922c97bd8e5dd2ac023e1def229da31'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at fe9beee9b Merge pull request #1565 from nouiz/nodev
# /usr/local/lib/python2.7/dist-packages/setuptools/dist.py:476: UserWarning: Normalizing '0.1dev' to '0.1.dev0'
#   normalized_version,
# running develop
# running egg_info
# creating pylearn2.egg-info
# writing requirements to pylearn2.egg-info/requires.txt
# writing pylearn2.egg-info/PKG-INFO
# writing top-level names to pylearn2.egg-info/top_level.txt
# writing dependency_links to pylearn2.egg-info/dependency_links.txt
# writing manifest file 'pylearn2.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# writing manifest file 'pylearn2.egg-info/SOURCES.txt'
# running build_ext
# cythoning pylearn2/utils/_window_flip.pyx to pylearn2/utils/_window_flip.c
# /usr/local/lib/python2.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/pylearn2/pylearn2/utils/_window_flip.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pylearn2.utils._window_flip' extension
# C compiler: x86_64-linux-gnu-gcc -pthread -fno-strict-aliasing -Wdate-time -D_FORTIFY_SOURCE=2 -g -fdebug-prefix-map=/build/python2.7-5Z483E/python2.7-2.7.17=. -fstack-protector-strong -Wformat -Werror=format-security -fPIC
#
# creating build
# creating build/temp.linux-x86_64-2.7
# creating build/temp.linux-x86_64-2.7/pylearn2
# creating build/temp.linux-x86_64-2.7/pylearn2/utils
# compile options: '-I/usr/local/lib/python2.7/dist-packages/numpy/core/include -I/usr/include/python2.7 -c'
# x86_64-linux-gnu-gcc: pylearn2/utils/_window_flip.c
# In file included from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1821:0,
#                  from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:18,
#                  from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from pylearn2/utils/_window_flip.c:598:
# /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: #warning "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it by " \
#   ^~~~~~~
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -fno-strict-aliasing -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -Wdate-time -D_FORTIFY_SOURCE=2 -g -fdebug-prefix-map=/build/python2.7-5Z483E/python2.7-2.7.17=. -fstack-protector-strong -Wformat -Werror=format-security -Wl,-Bsymbolic-functions -Wl,-z,relro -Wdate-time -D_FORTIFY_SOURCE=2 -g -fdebug-prefix-map=/build/python2.7-5Z483E/python2.7-2.7.17=. -fstack-protector-strong -Wformat -Werror=format-security -fPIC build/temp.linux-x86_64-2.7/pylearn2/utils/_window_flip.o -o /content/pylearn2/pylearn2/utils/_window_flip.so
# cythoning pylearn2/utils/_video.pyx to pylearn2/utils/_video.c
# /usr/local/lib/python2.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/pylearn2/pylearn2/utils/_video.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pylearn2.utils._video' extension
# C compiler: x86_64-linux-gnu-gcc -pthread -fno-strict-aliasing -Wdate-time -D_FORTIFY_SOURCE=2 -g -fdebug-prefix-map=/build/python2.7-5Z483E/python2.7-2.7.17=. -fstack-protector-strong -Wformat -Werror=format-security -fPIC
#
# compile options: '-I/usr/local/lib/python2.7/dist-packages/numpy/core/include -I/usr/include/python2.7 -c'
# x86_64-linux-gnu-gcc: pylearn2/utils/_video.c
# In file included from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1821:0,
#                  from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/ndarrayobject.h:18,
#                  from /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from pylearn2/utils/_video.c:598:
# /usr/local/lib/python2.7/dist-packages/numpy/core/include/numpy/npy_1_7_deprecated_api.h:15:2: warning: #warning "Using deprecated NumPy API, disable it by " "#defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION" [-Wcpp]
#  #warning "Using deprecated NumPy API, disable it by " \
#   ^~~~~~~
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -fno-strict-aliasing -DNDEBUG -g -fwrapv -O2 -Wall -Wstrict-prototypes -Wdate-time -D_FORTIFY_SOURCE=2 -g -fdebug-prefix-map=/build/python2.7-5Z483E/python2.7-2.7.17=. -fstack-protector-strong -Wformat -Werror=format-security -Wl,-Bsymbolic-functions -Wl,-z,relro -Wdate-time -D_FORTIFY_SOURCE=2 -g -fdebug-prefix-map=/build/python2.7-5Z483E/python2.7-2.7.17=. -fstack-protector-strong -Wformat -Werror=format-security -fPIC build/temp.linux-x86_64-2.7/pylearn2/utils/_video.o -o /content/pylearn2/pylearn2/utils/_video.so
# Creating /usr/local/lib/python2.7/dist-packages/pylearn2.egg-link (link to .)
# Adding pylearn2 0.1.dev0 to easy-install.pth file
# Installing pylearn2-plot-monitor script to /usr/local/bin
# Installing pylearn2-print-monitor script to /usr/local/bin
# Installing pylearn2-show-examples script to /usr/local/bin
# Installing pylearn2-show-weights script to /usr/local/bin
# Installing pylearn2-train script to /usr/local/bin
#
# Installed /content/pylearn2
# Processing dependencies for pylearn2==0.1.dev0
# Searching for Theano==0.8.0.dev0
# Best match: Theano 0.8.0.dev0
# Adding Theano 0.8.0.dev0 to easy-install.pth file
#
# Using /usr/local/lib/python2.7/dist-packages
# Searching for argparse==1.2.1
# Best match: argparse 1.2.1
# Adding argparse 1.2.1 to easy-install.pth file
#
# Using /usr/lib/python2.7
# Searching for PyYAML==3.13
# Best match: PyYAML 3.13
# Adding PyYAML 3.13 to easy-install.pth file
#
# Using /usr/local/lib/python2.7/dist-packages
# Searching for numpy==1.15.4
# Best match: numpy 1.15.4
# Adding numpy 1.15.4 to easy-install.pth file
#
# Using /usr/local/lib/python2.7/dist-packages
# Searching for scipy==1.2.2
# Best match: scipy 1.2.2
# Adding scipy 1.2.2 to easy-install.pth file
#
# Using /usr/local/lib/python2.7/dist-packages
# Searching for six==1.12.0
# Best match: six 1.12.0
# Adding six 1.12.0 to easy-install.pth file
#
# Using /usr/local/lib/python2.7/dist-packages
# Finished processing dependencies for pylearn2==0.1.dev0
# /content
# /content/pylearn2/pylearn2/datasets/mnist
# --2020-03-04 21:14:46--  http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Resolving yann.lecun.com (yann.lecun.com)... 104.28.6.204, 104.28.7.204, 2606:4700:3033::681c:7cc, ...
# Connecting to yann.lecun.com (yann.lecun.com)|104.28.6.204|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9912422 (9.5M) [application/x-gzip]
# Saving to: ‘train-images-idx3-ubyte.gz’
#
# train-images-idx3-u 100%[===================>]   9.45M  13.2MB/s    in 0.7s
#
# 2020-03-04 21:14:46 (13.2 MB/s) - ‘train-images-idx3-ubyte.gz’ saved [9912422/9912422]
#
# --2020-03-04 21:14:47--  http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Resolving yann.lecun.com (yann.lecun.com)... 104.28.7.204, 104.28.6.204, 2606:4700:3033::681c:7cc, ...
# Connecting to yann.lecun.com (yann.lecun.com)|104.28.7.204|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28881 (28K) [application/x-gzip]
# Saving to: ‘train-labels-idx1-ubyte.gz’
#
# train-labels-idx1-u 100%[===================>]  28.20K  --.-KB/s    in 0.07s
#
# 2020-03-04 21:14:48 (430 KB/s) - ‘train-labels-idx1-ubyte.gz’ saved [28881/28881]
#
# --2020-03-04 21:14:49--  http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Resolving yann.lecun.com (yann.lecun.com)... 104.28.7.204, 104.28.6.204, 2606:4700:3033::681c:7cc, ...
# Connecting to yann.lecun.com (yann.lecun.com)|104.28.7.204|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1648877 (1.6M) [application/x-gzip]
# Saving to: ‘t10k-images-idx3-ubyte.gz’
#
# t10k-images-idx3-ub 100%[===================>]   1.57M  3.78MB/s    in 0.4s
#
# 2020-03-04 21:14:49 (3.78 MB/s) - ‘t10k-images-idx3-ubyte.gz’ saved [1648877/1648877]
#
# --2020-03-04 21:14:50--  http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Resolving yann.lecun.com (yann.lecun.com)... 104.28.7.204, 104.28.6.204, 2606:4700:3033::681c:7cc, ...
# Connecting to yann.lecun.com (yann.lecun.com)|104.28.7.204|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4542 (4.4K) [application/x-gzip]
# Saving to: ‘t10k-labels-idx1-ubyte.gz’
#
# t10k-labels-idx1-ub 100%[===================>]   4.44K  --.-KB/s    in 0s
#
# 2020-03-04 21:14:50 (369 MB/s) - ‘t10k-labels-idx1-ubyte.gz’ saved [4542/4542]
#
# /content
# Cloning into 'Lasagne'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 6179 (delta 2), reused 6 (delta 1), pack-reused 6168
# Receiving objects: 100% (6179/6179), 2.21 MiB | 22.42 MiB/s, done.
# Resolving deltas: 100% (4460/4460), done.
# /content/Lasagne
# Note: checking out '6a559dd54e0cc4930c9b29319fe45350d1a651e6'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at 6a559dd don't use O(N^2) algorithm in get_all_params
# Processing /content/Lasagne
# Requirement already satisfied: numpy in /usr/local/lib/python2.7/dist-packages (from Lasagne==0.2.dev1) (1.15.4)
# Building wheels for collected packages: Lasagne
#   Building wheel for Lasagne (setup.py) ... done
#   Created wheel for Lasagne: filename=Lasagne-0.2.dev1-cp27-none-any.whl size=97798 sha256=1675c2a5e42b9223a3c371d08170bacde95cfb98d3dd424f9f64cefdb0ff7151
#   Stored in directory: /tmp/pip-ephem-wheel-cache-lmSQej/wheels/d2/1a/45/cb9f5893035355d9a9601670012ccf7945510d95415d8cc218
# Successfully built Lasagne
# Installing collected packages: Lasagne
# Successfully installed Lasagne-0.2.dev1
# /content
# Cloning into 'PyTables'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 30687 (delta 6), reused 9 (delta 4), pack-reused 30670
# Receiving objects: 100% (30687/30687), 34.56 MiB | 29.76 MiB/s, done.
# Resolving deltas: 100% (24155/24155), done.
# /content/PyTables
# Note: checking out '73221baf85afda517bc0646f448ffb3f8e51dd81'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at 73221baf Merge pull request #523 from Dapid/fix_which_lib_docstring
# Processing /content/PyTables
# Requirement already satisfied: numpy>=1.7.1 in /usr/local/lib/python2.7/dist-packages (from tables==3.2.2.dev0) (1.15.4)
# Requirement already satisfied: numexpr>=2.4 in /usr/local/lib/python2.7/dist-packages (from tables==3.2.2.dev0) (2.6.9)
# Requirement already satisfied: six in /usr/local/lib/python2.7/dist-packages (from tables==3.2.2.dev0) (1.12.0)
# Building wheels for collected packages: tables
#   Building wheel for tables (setup.py) ... done
#   Created wheel for tables: filename=tables-3.2.2.dev0-cp27-cp27mu-linux_x86_64.whl size=2181977 sha256=bb6cd64d4a5151b3310cc07b6e735a475ae66c199c5230c1857a263f9ebcd850
#   Stored in directory: /tmp/pip-ephem-wheel-cache-M5vvxt/wheels/90/ac/bc/01ef5d22d5135e9374e75e3e61c00171048ccf994cd350be86
# Successfully built tables
# Installing collected packages: tables
#   Found existing installation: tables 3.4.4
#     Uninstalling tables-3.4.4:
#       Successfully uninstalled tables-3.4.4
# Successfully installed tables-3.2.2.dev0
# /content

# %% [markdown]
# ## Step 2: Mount your google drive (Optional but Reccomended)

# %%
#Step 2: Mount your google drive (OPTIONAL)
###########################################

#Mount the google drive
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/collab/
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# /content/gdrive/My Drive/collab

# %% [markdown]
# ## Step 3: Clone the SFC repository

# %%
#Step 3: Clone the SFC repository
#################################

#clone the repo
# !git clone https://github.com/fcaspe/BNN-PYNQ-ZYBO
# Out:
# Cloning into 'BNN-PYNQ'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 4896 (delta 8), reused 13 (delta 5), pack-reused 4878
# Receiving objects: 100% (4896/4896), 186.12 MiB | 19.25 MiB/s, done.
# Resolving deltas: 100% (844/844), done.
# Checking out files: 100% (1846/1846), done.

# %% [markdown]
# ## Step 4: Set pylearn and launch the train script.
#
# A .npz pickle file will be generated each time a better epoch is found.
#
# Please store this file after running the script as it contains the layers' structure of our BNN.

# %%
#Step 4: Set pylearn and launch the train script
################################################

# %cd ./BNN-PYNQ-ZYBO/bnn/src/training/

import os,sys
os.environ['PYLEARN2_VIEWER_COMMAND'] = 'eog --new-instance'
os.environ['PYLEARN2_DATA_PATH'] = '/content/pylearn2/pylearn2/datasets'
os.environ['PYTHONPATH'] = '/content/pylearn2'

! python2 sfc_train_mnist.py
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 446 of 1000 took 23.6086471081s
#   LR:                            4.97876072231e-05
#   training loss:                 0.06443967026098141
#   validation loss:               0.02728317373724847
#   validation error rate:         3.789999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 447 of 1000 took 23.5660390854s
#   LR:                            4.93311516964e-05
#   training loss:                 0.06392939713749556
#   validation loss:               0.028166580732586804
#   validation error rate:         3.929999999999998%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 448 of 1000 took 23.6619560719s
#   LR:                            4.88788809792e-05
#   training loss:                 0.06429272872604147
#   validation loss:               0.026466042558642378
#   validation error rate:         3.759999999999998%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 449 of 1000 took 23.6912121773s
#   LR:                            4.84307567048e-05
#   training loss:                 0.06467019517090268
#   validation loss:               0.02779772459036987
#   validation error rate:         3.7399999999999967%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 450 of 1000 took 23.5358438492s
#   LR:                            4.79867408584e-05
#   training loss:                 0.06309414839270437
#   validation loss:               0.027557090134298384
#   validation error rate:         3.819999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 451 of 1000 took 23.7819600105s
#   LR:                            4.75467957738e-05
#   training loss:                 0.06406115896546069
#   validation loss:               0.027642889919522684
#   validation error rate:         3.9399999999999955%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 452 of 1000 took 23.8039908409s
#   LR:                            4.711088413e-05
#   training loss:                 0.06369824541805313
#   validation loss:               0.028472935385187262
#   validation error rate:         3.819999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 453 of 1000 took 23.7310600281s
#   LR:                            4.66789689482e-05
#   training loss:                 0.06359527460553333
#   validation loss:               0.02810275198670241
#   validation error rate:         3.949999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 454 of 1000 took 23.9471259117s
#   LR:                            4.62510135885e-05
#   training loss:                 0.06359934904588953
#   validation loss:               0.028412654265892203
#   validation error rate:         4.009999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 455 of 1000 took 23.9442350864s
#   LR:                            4.58269817471e-05
#   training loss:                 0.06409338712517842
#   validation loss:               0.028131949752628334
#   validation error rate:         3.9299999999999966%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 456 of 1000 took 23.7668251991s
#   LR:                            4.54068374531e-05
#   training loss:                 0.06332270305559712
#   validation loss:               0.027253042111681842
#   validation error rate:         3.939999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 457 of 1000 took 23.7849781513s
#   LR:                            4.49905450651e-05
#   training loss:                 0.06350834983090962
#   validation loss:               0.028466286157798445
#   validation error rate:         3.9799999999999973%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 458 of 1000 took 23.8273301125s
#   LR:                            4.45780692686e-05
#   training loss:                 0.06243844138887911
#   validation loss:               0.027116674776270472
#   validation error rate:         3.859999999999999%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 459 of 1000 took 23.8187501431s
#   LR:                            4.4169375073e-05
#   training loss:                 0.06438667516733523
#   validation loss:               0.026920724937653594
#   validation error rate:         3.739999999999998%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 460 of 1000 took 23.5530939102s
#   LR:                            4.37644278083e-05
#   training loss:                 0.06418496199869156
#   validation loss:               0.02782271240193129
#   validation error rate:         3.8099999999999974%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 461 of 1000 took 23.7144160271s
#   LR:                            4.33631931224e-05
#   training loss:                 0.06343995956250424
#   validation loss:               0.027838929439808334
#   validation error rate:         3.9499999999999966%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 462 of 1000 took 23.8611168861s
#   LR:                            4.29656369782e-05
#   training loss:                 0.06325611920949913
#   validation loss:               0.027132157671642915
#   validation error rate:         3.719999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 463 of 1000 took 23.6440069675s
#   LR:                            4.25717256507e-05
#   training loss:                 0.06426453871216616
#   validation loss:               0.027027665313390167
#   validation error rate:         3.7499999999999964%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 464 of 1000 took 23.7875030041s
#   LR:                            4.21814257239e-05
#   training loss:                 0.06410807804750547
#   validation loss:               0.027649130526472932
#   validation error rate:         3.789999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 465 of 1000 took 23.6354789734s
#   LR:                            4.17947040884e-05
#   training loss:                 0.06447210958847373
#   validation loss:               0.027799589666464963
#   validation error rate:         3.8599999999999977%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 466 of 1000 took 23.6629090309s
#   LR:                            4.14115279381e-05
#   training loss:                 0.06276940982077349
#   validation loss:               0.027838900092952187
#   validation error rate:         3.9199999999999973%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 467 of 1000 took 23.8913180828s
#   LR:                            4.10318647679e-05
#   training loss:                 0.06324977148697203
#   validation loss:               0.026853916435588304
#   validation error rate:         3.749999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 468 of 1000 took 23.7998290062s
#   LR:                            4.06556823705e-05
#   training loss:                 0.06358484448339141
#   validation loss:               0.027414350666974726
#   validation error rate:         3.889999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 469 of 1000 took 23.6155531406s
#   LR:                            4.02829488341e-05
#   training loss:                 0.0629989736534211
#   validation loss:               0.02648563519911987
#   validation error rate:         3.699999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 470 of 1000 took 23.4866728783s
#   LR:                            3.99136325393e-05
#   training loss:                 0.06302493402397273
#   validation loss:               0.027763570370614703
#   validation error rate:         3.889999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 471 of 1000 took 23.5820178986s
#   LR:                            3.95477021567e-05
#   training loss:                 0.06337555785855675
#   validation loss:               0.027388554243582094
#   validation error rate:         3.819999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 472 of 1000 took 23.7035939693s
#   LR:                            3.9185126644e-05
#   training loss:                 0.06354243465046538
#   validation loss:               0.028146538972672493
#   validation error rate:         3.869999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 473 of 1000 took 23.5758988857s
#   LR:                            3.88258752435e-05
#   training loss:                 0.06322065423841255
#   validation loss:               0.027988598816517034
#   validation error rate:         4.0099999999999945%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 474 of 1000 took 23.7403030396s
#   LR:                            3.84699174797e-05
#   training loss:                 0.06230264128012185
#   validation loss:               0.027933210372662498
#   validation error rate:         3.9899999999999984%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 475 of 1000 took 23.6128721237s
#   LR:                            3.81172231563e-05
#   training loss:                 0.06297911122387741
#   validation loss:               0.027681122138977998
#   validation error rate:         3.7599999999999976%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 476 of 1000 took 23.6858019829s
#   LR:                            3.77677623538e-05
#   training loss:                 0.06438485872987784
#   validation loss:               0.026799288293486802
#   validation error rate:         3.759999999999998%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 477 of 1000 took 23.823846817s
#   LR:                            3.74215054273e-05
#   training loss:                 0.06336971868550645
#   validation loss:               0.027180532828169474
#   validation error rate:         3.829999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 478 of 1000 took 23.5662970543s
#   LR:                            3.70784230033e-05
#   training loss:                 0.06297593499128716
#   validation loss:               0.02795568734619106
#   validation error rate:         3.9099999999999966%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 479 of 1000 took 23.6340630054s
#   LR:                            3.6738485978e-05
#   training loss:                 0.06350587653969167
#   validation loss:               0.02735527409412378
#   validation error rate:         3.7899999999999956%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 480 of 1000 took 23.7703192234s
#   LR:                            3.64016655139e-05
#   training loss:                 0.06277858677181472
#   validation loss:               0.02688390969729477
#   validation error rate:         3.849999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 481 of 1000 took 23.9036829472s
#   LR:                            3.60679330385e-05
#   training loss:                 0.06361367329442236
#   validation loss:               0.027763784373216586
#   validation error rate:         3.9699999999999966%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 482 of 1000 took 23.8183140755s
#   LR:                            3.57372602408e-05
#   training loss:                 0.06353903014745635
#   validation loss:               0.027502266265731802
#   validation error rate:         3.819999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 483 of 1000 took 23.8206059933s
#   LR:                            3.54096190696e-05
#   training loss:                 0.06350899257743928
#   validation loss:               0.027276162364154248
#   validation error rate:         3.869999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 484 of 1000 took 23.7545239925s
#   LR:                            3.50849817306e-05
#   training loss:                 0.06307394451796497
#   validation loss:               0.0276138514026235
#   validation error rate:         3.7999999999999963%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 485 of 1000 took 23.6986069679s
#   LR:                            3.47633206847e-05
#   training loss:                 0.06286950136407435
#   validation loss:               0.027807927368095627
#   validation error rate:         3.8199999999999985%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 486 of 1000 took 23.6914849281s
#   LR:                            3.44446086449e-05
#   training loss:                 0.06297182408192718
#   validation loss:               0.026797372279203466
#   validation error rate:         3.7799999999999967%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 487 of 1000 took 23.7622790337s
#   LR:                            3.41288185747e-05
#   training loss:                 0.06290483256715176
#   validation loss:               0.028214858235681244
#   validation error rate:         4.019999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 488 of 1000 took 23.578181982s
#   LR:                            3.38159236853e-05
#   training loss:                 0.06327393184118102
#   validation loss:               0.02731750594556158
#   validation error rate:         3.7399999999999967%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 489 of 1000 took 23.6318898201s
#   LR:                            3.35058974334e-05
#   training loss:                 0.06402735502750259
#   validation loss:               0.02671094446613625
#   validation error rate:         3.6199999999999983%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 490 of 1000 took 23.5671768188s
#   LR:                            3.31987135193e-05
#   training loss:                 0.06338122777428241
#   validation loss:               0.027150852457478388
#   validation error rate:         3.829999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 491 of 1000 took 23.5172700882s
#   LR:                            3.28943458843e-05
#   training loss:                 0.06229024676192836
#   validation loss:               0.02799589829789972
#   validation error rate:         3.7299999999999986%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 492 of 1000 took 23.721200943s
#   LR:                            3.25927687085e-05
#   training loss:                 0.06377668023284566
#   validation loss:               0.02810217996542571
#   validation error rate:         3.9699999999999966%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 493 of 1000 took 23.7712078094s
#   LR:                            3.22939564089e-05
#   training loss:                 0.06342631525590778
#   validation loss:               0.026773609450845327
#   validation error rate:         3.7899999999999974%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 494 of 1000 took 23.9218699932s
#   LR:                            3.19978836369e-05
#   training loss:                 0.0631880930102872
#   validation loss:               0.026957496663541556
#   validation error rate:         3.669999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 495 of 1000 took 23.6643278599s
#   LR:                            3.17045252764e-05
#   training loss:                 0.0631229408645798
#   validation loss:               0.027431159288664755
#   validation error rate:         3.8699999999999966%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 496 of 1000 took 23.5612859726s
#   LR:                            3.14138564415e-05
#   training loss:                 0.06385647079157543
#   validation loss:               0.02773285001149445
#   validation error rate:         3.8599999999999968%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 497 of 1000 took 23.7881510258s
#   LR:                            3.11258524745e-05
#   training loss:                 0.06315590409939181
#   validation loss:               0.027220184155207567
#   validation error rate:         3.8299999999999965%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 498 of 1000 took 23.6642558575s
#   LR:                            3.08404889438e-05
#   training loss:                 0.062372084733313245
#   validation loss:               0.027432406987101234
#   validation error rate:         3.8099999999999983%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 499 of 1000 took 23.7102639675s
#   LR:                            3.05577416416e-05
#   training loss:                 0.06312458744336327
#   validation loss:               0.02731036756715901
#   validation error rate:         3.849999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 500 of 1000 took 23.7035939693s
#   LR:                            3.02775865823e-05
#   training loss:                 0.06309814459393334
#   validation loss:               0.026793195846143196
#   validation error rate:         3.7299999999999973%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 501 of 1000 took 23.6023449898s
#   LR:                            3e-05
#   training loss:                 0.06372073507906083
#   validation loss:               0.027283017134302943
#   validation error rate:         3.9199999999999964%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 502 of 1000 took 23.8047180176s
#   LR:                            2.97249583468e-05
#   training loss:                 0.06386405334013649
#   validation loss:               0.027741674400292165
#   validation error rate:         3.739999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 503 of 1000 took 23.7430620193s
#   LR:                            2.94524382906e-05
#   training loss:                 0.06351825836757147
#   validation loss:               0.028072991027716133
#   validation error rate:         3.9399999999999977%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 504 of 1000 took 23.7937259674s
#   LR:                            2.91824167133e-05
#   training loss:                 0.0631493276983289
#   validation loss:               0.02715080648903742
#   validation error rate:         3.799999999999995%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 505 of 1000 took 23.9054949284s
#   LR:                            2.89148707087e-05
#   training loss:                 0.06245392870318062
#   validation loss:               0.028153025037200692
#   validation error rate:         3.8199999999999963%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 506 of 1000 took 23.9376828671s
#   LR:                            2.86497775806e-05
#   training loss:                 0.06347013012662334
#   validation loss:               0.027957457035809194
#   validation error rate:         3.9099999999999984%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 507 of 1000 took 24.2474150658s
#   LR:                            2.8387114841e-05
#   training loss:                 0.06325051893735277
#   validation loss:               0.028372986330524673
#   validation error rate:         3.9999999999999973%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 508 of 1000 took 23.8638429642s
#   LR:                            2.81268602078e-05
#   training loss:                 0.06375040238769977
#   validation loss:               0.026778649003601766
#   validation error rate:         3.869999999999998%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 509 of 1000 took 23.8824989796s
#   LR:                            2.78689916034e-05
#   training loss:                 0.06305854835609359
#   validation loss:               0.027757211309732563
#   validation error rate:         3.8999999999999972%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 510 of 1000 took 23.9059751034s
#   LR:                            2.76134871526e-05
#   training loss:                 0.06389522497016176
#   validation loss:               0.02735060693505469
#   validation error rate:         3.8399999999999963%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 511 of 1000 took 23.7755858898s
#   LR:                            2.73603251807e-05
#   training loss:                 0.06432015408463292
#   validation loss:               0.027708922643531766
#   validation error rate:         3.789999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 512 of 1000 took 23.913533926s
#   LR:                            2.71094842117e-05
#   training loss:                 0.06278109755504108
#   validation loss:               0.02804445759432577
#   validation error rate:         3.8999999999999977%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 513 of 1000 took 23.6786439419s
#   LR:                            2.68609429665e-05
#   training loss:                 0.06250361287901154
#   validation loss:               0.027579958510673627
#   validation error rate:         3.879999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 514 of 1000 took 23.8088359833s
#   LR:                            2.66146803611e-05
#   training loss:                 0.06263231502083692
#   validation loss:               0.02601796521240324
#   validation error rate:         3.7599999999999976%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 515 of 1000 took 23.8083519936s
#   LR:                            2.63706755049e-05
#   training loss:                 0.06377419919103264
#   validation loss:               0.02794291794646353
#   validation error rate:         3.8599999999999977%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 516 of 1000 took 23.6665360928s
#   LR:                            2.61289076987e-05
#   training loss:                 0.06163476100880396
#   validation loss:               0.028339841505481564
#   validation error rate:         3.859999999999998%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 517 of 1000 took 23.8197638988s
#   LR:                            2.5889356433e-05
#   training loss:                 0.06352739866274323
#   validation loss:               0.027787934387575854
#   validation error rate:         3.7599999999999976%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 518 of 1000 took 23.6642158031s
#   LR:                            2.56520013865e-05
#   training loss:                 0.06338252121373104
#   validation loss:               0.027344839802730517
#   validation error rate:         3.8599999999999977%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 519 of 1000 took 23.9135599136s
#   LR:                            2.54168224242e-05
#   training loss:                 0.06285191543865419
#   validation loss:               0.027035053646728882
#   validation error rate:         3.7699999999999996%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 520 of 1000 took 23.9165940285s
#   LR:                            2.51837995956e-05
#   training loss:                 0.06367871117088143
#   validation loss:               0.027340674609157966
#   validation error rate:         3.829999999999998%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 521 of 1000 took 23.6631338596s
#   LR:                            2.49529131331e-05
#   training loss:                 0.06253718719447332
#   validation loss:               0.02660725932465073
#   validation error rate:         3.7799999999999954%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 522 of 1000 took 23.7989170551s
#   LR:                            2.47241434504e-05
#   training loss:                 0.06334575070291527
#   validation loss:               0.028166539561190827
#   validation error rate:         3.8799999999999972%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 523 of 1000 took 23.6685359478s
#   LR:                            2.44974711408e-05
#   training loss:                 0.06290212729299578
#   validation loss:               0.027201647279090947
#   validation error rate:         3.7999999999999963%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 524 of 1000 took 23.8358650208s
#   LR:                            2.42728769754e-05
#   training loss:                 0.062518519519501
#   validation loss:               0.027427077214395218
#   validation error rate:         3.7899999999999956%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 525 of 1000 took 23.9810760021s
#   LR:                            2.40503419016e-05
#   training loss:                 0.062142526780298225
#   validation loss:               0.02675414428654835
#   validation error rate:         3.6699999999999964%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 526 of 1000 took 23.7756669521s
#   LR:                            2.38298470417e-05
#   training loss:                 0.06226276407714313
#   validation loss:               0.02712286020623806
#   validation error rate:         3.799999999999997%
#   best epoch:                    382
#   best validation error rate:    3.6099999999999985%
#   test loss:                     0.029770278056430715
#   test error rate:               4.129999999999996%
# Epoch 527 of 1000 took 25.5289120674s
#   LR:                            2.36113736909e-05
#   training loss:                 0.06343231617656903
#   validation loss:               0.026257981219821237
#   validation error rate:         3.529999999999997%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 528 of 1000 took 23.7393701077s
#   LR:                            2.33949033157e-05
#   training loss:                 0.06245792040939394
#   validation loss:               0.02767922695139594
#   validation error rate:         3.8199999999999985%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 529 of 1000 took 23.8385109901s
#   LR:                            2.31804175529e-05
#   training loss:                 0.0626425491743102
#   validation loss:               0.027458480001851856
#   validation error rate:         3.739999999999998%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 530 of 1000 took 23.8178870678s
#   LR:                            2.29678982073e-05
#   training loss:                 0.06330120866572604
#   validation loss:               0.02776735385084613
#   validation error rate:         3.6899999999999973%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 531 of 1000 took 23.6252419949s
#   LR:                            2.27573272509e-05
#   training loss:                 0.06231018349288939
#   validation loss:               0.026654709867676755
#   validation error rate:         3.749999999999998%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 532 of 1000 took 24.0591850281s
#   LR:                            2.25486868205e-05
#   training loss:                 0.06266836191214749
#   validation loss:               0.026973794796020488
#   validation error rate:         3.669999999999997%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 533 of 1000 took 23.9131300449s
#   LR:                            2.23419592172e-05
#   training loss:                 0.06353765835491615
#   validation loss:               0.026906903974072055
#   validation error rate:         3.819999999999997%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 534 of 1000 took 23.9149899483s
#   LR:                            2.21371269039e-05
#   training loss:                 0.06311554953143295
#   validation loss:               0.02835960524276329
#   validation error rate:         4.019999999999998%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 535 of 1000 took 23.9027478695s
#   LR:                            2.19341725045e-05
#   training loss:                 0.06219371299644998
#   validation loss:               0.027850223216983362
#   validation error rate:         3.799999999999995%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 536 of 1000 took 23.6641499996s
#   LR:                            2.17330788023e-05
#   training loss:                 0.0636865227292927
#   validation loss:               0.026949023279934516
#   validation error rate:         3.7899999999999956%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 537 of 1000 took 23.9673249722s
#   LR:                            2.15338287381e-05
#   training loss:                 0.0626831372465139
#   validation loss:               0.027562730027163897
#   validation error rate:         3.849999999999995%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 538 of 1000 took 23.6718361378s
#   LR:                            2.13364054096e-05
#   training loss:                 0.06199505849867976
#   validation loss:               0.027232993722101445
#   validation error rate:         3.9199999999999973%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 539 of 1000 took 23.7705738544s
#   LR:                            2.1140792069e-05
#   training loss:                 0.06277668144601554
#   validation loss:               0.027592723075976603
#   validation error rate:         3.819999999999995%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 540 of 1000 took 23.8383948803s
#   LR:                            2.09469721223e-05
#   training loss:                 0.0627419200551557
#   validation loss:               0.02747093461033305
#   validation error rate:         3.9499999999999966%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 541 of 1000 took 23.6064450741s
#   LR:                            2.07549291276e-05
#   training loss:                 0.06349313154140798
#   validation loss:               0.0270742319083611
#   validation error rate:         3.609999999999998%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 542 of 1000 took 23.8865828514s
#   LR:                            2.05646467936e-05
#   training loss:                 0.06218779287167708
#   validation loss:               0.028056317144073042
#   validation error rate:         3.9899999999999958%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 543 of 1000 took 23.7449018955s
#   LR:                            2.03761089785e-05
#   training loss:                 0.06280349364739679
#   validation loss:               0.02810665409991756
#   validation error rate:         3.929999999999996%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 544 of 1000 took 23.7637748718s
#   LR:                            2.01892996885e-05
#   training loss:                 0.06310511908681884
#   validation loss:               0.027488671238267672
#   validation error rate:         3.879999999999997%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 545 of 1000 took 24.0529630184s
#   LR:                            2.00042030764e-05
#   training loss:                 0.06201380443883379
#   validation loss:               0.027831919776144784
#   validation error rate:         3.839999999999998%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 546 of 1000 took 23.7366359234s
#   LR:                            1.98208034402e-05
#   training loss:                 0.06326879402154938
#   validation loss:               0.02844493159511967
#   validation error rate:         3.9099999999999975%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 547 of 1000 took 23.857640028s
#   LR:                            1.9639085222e-05
#   training loss:                 0.06252193363649107
#   validation loss:               0.02766085455385684
#   validation error rate:         3.809999999999996%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 548 of 1000 took 23.6331391335s
#   LR:                            1.94590330064e-05
#   training loss:                 0.06320569295921578
#   validation loss:               0.026772315594131763
#   validation error rate:         3.689999999999997%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 549 of 1000 took 23.7979469299s
#   LR:                            1.92806315195e-05
#   training loss:                 0.06301593907481248
#   validation loss:               0.02729101941832504
#   validation error rate:         3.879999999999996%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 550 of 1000 took 23.8098168373s
#   LR:                            1.91038656272e-05
#   training loss:                 0.06273552083202581
#   validation loss:               0.028311577726797408
#   validation error rate:         3.8099999999999987%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 551 of 1000 took 23.5289900303s
#   LR:                            1.89287203344e-05
#   training loss:                 0.062059703007218026
#   validation loss:               0.02825445355083682
#   validation error rate:         3.9199999999999964%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 552 of 1000 took 23.7721819878s
#   LR:                            1.87551807833e-05
#   training loss:                 0.062332437213222146
#   validation loss:               0.027393805868212544
#   validation error rate:         3.9199999999999977%
#   best epoch:                    527
#   best validation error rate:    3.529999999999997%
#   test loss:                     0.0286376171481861
#   test error rate:               3.9699999999999966%
# Epoch 553 of 1000 took 23.7366368771s
#   LR:                            1.85832322523e-05
#   training loss:                 0.06229962075994791
#   validation loss:               0.027114578384771305
#   validation error rate:         3.9099999999999984%
#   best epoch:                    527
# ...
# Epoch 965 of 1000 took 25.4878749847s
#   LR:                            4.17947040884e-07
#   training loss:                 0.06182581065767499
#   validation loss:               0.02573703818117199
#   validation error rate:         3.4399999999999973%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 966 of 1000 took 23.9724030495s
#   LR:                            4.14115279381e-07
#   training loss:                 0.06087851694648056
#   validation loss:               0.027081747459791018
#   validation error rate:         3.719999999999997%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 967 of 1000 took 24.0881638527s
#   LR:                            4.10318647679e-07
#   training loss:                 0.061366445329319036
#   validation loss:               0.027336023971761114
#   validation error rate:         3.8599999999999977%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 968 of 1000 took 24.0486719608s
#   LR:                            4.06556823705e-07
#   training loss:                 0.05989096414932649
#   validation loss:               0.026726165734275217
#   validation error rate:         3.6799999999999966%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 969 of 1000 took 24.0759100914s
#   LR:                            4.02829488341e-07
#   training loss:                 0.0618241167925719
#   validation loss:               0.026834255709132365
#   validation error rate:         3.6999999999999984%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 970 of 1000 took 23.9711871147s
#   LR:                            3.99136325393e-07
#   training loss:                 0.06146036929817826
#   validation loss:               0.027042171911344934
#   validation error rate:         3.8399999999999967%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 971 of 1000 took 24.1705610752s
#   LR:                            3.95477021567e-07
#   training loss:                 0.06096542439940376
#   validation loss:               0.026064669933617637
#   validation error rate:         3.6399999999999966%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 972 of 1000 took 23.9887859821s
#   LR:                            3.9185126644e-07
#   training loss:                 0.0610003312193596
#   validation loss:               0.02736692028182387
#   validation error rate:         3.6699999999999977%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 973 of 1000 took 23.9739141464s
#   LR:                            3.88258752435e-07
#   training loss:                 0.061549296777738384
#   validation loss:               0.027068527743338646
#   validation error rate:         3.7999999999999963%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 974 of 1000 took 23.9191031456s
#   LR:                            3.84699174797e-07
#   training loss:                 0.06149741782872475
#   validation loss:               0.02692437208041998
#   validation error rate:         3.759999999999998%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 975 of 1000 took 23.9305360317s
#   LR:                            3.81172231563e-07
#   training loss:                 0.060901350912639575
#   validation loss:               0.02638447369647017
#   validation error rate:         3.709999999999998%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 976 of 1000 took 23.8955500126s
#   LR:                            3.77677623538e-07
#   training loss:                 0.060429545418832546
#   validation loss:               0.027229925074759534
#   validation error rate:         3.7999999999999963%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 977 of 1000 took 23.9494059086s
#   LR:                            3.74215054273e-07
#   training loss:                 0.061433772891935905
#   validation loss:               0.02575548809492083
#   validation error rate:         3.7599999999999976%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 978 of 1000 took 24.1773920059s
#   LR:                            3.70784230033e-07
#   training loss:                 0.060159123931847656
#   validation loss:               0.026004062418897765
#   validation error rate:         3.639999999999999%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 979 of 1000 took 23.935983181s
#   LR:                            3.6738485978e-07
#   training loss:                 0.061538126088807085
#   validation loss:               0.026724632524981706
#   validation error rate:         3.769999999999997%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 980 of 1000 took 23.8877301216s
#   LR:                            3.6401665514e-07
#   training loss:                 0.06235753769818875
#   validation loss:               0.02655240746844488
#   validation error rate:         3.599999999999997%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 981 of 1000 took 23.6494100094s
#   LR:                            3.60679330385e-07
#   training loss:                 0.060338529796767584
#   validation loss:               0.026791387303187874
#   validation error rate:         3.6999999999999975%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 982 of 1000 took 23.7011339664s
#   LR:                            3.57372602408e-07
#   training loss:                 0.06150174257909353
#   validation loss:               0.02666447105759367
#   validation error rate:         3.639999999999998%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 983 of 1000 took 23.7307219505s
#   LR:                            3.54096190696e-07
#   training loss:                 0.060927477113437795
#   validation loss:               0.02739073644479563
#   validation error rate:         3.899999999999995%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 984 of 1000 took 23.882887125s
#   LR:                            3.50849817306e-07
#   training loss:                 0.060599819373060554
#   validation loss:               0.02640490764330626
#   validation error rate:         3.6299999999999963%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 985 of 1000 took 23.7180030346s
#   LR:                            3.47633206847e-07
#   training loss:                 0.061196766164789716
#   validation loss:               0.02728599744418852
#   validation error rate:         3.7299999999999973%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 986 of 1000 took 23.8017730713s
#   LR:                            3.44446086449e-07
#   training loss:                 0.06168680381000879
#   validation loss:               0.0267363967535172
#   validation error rate:         3.7399999999999967%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 987 of 1000 took 23.875177145s
#   LR:                            3.41288185747e-07
#   training loss:                 0.061220650397687974
#   validation loss:               0.026665512710550416
#   validation error rate:         3.6499999999999964%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 988 of 1000 took 23.8679308891s
#   LR:                            3.38159236853e-07
#   training loss:                 0.060874289408158574
#   validation loss:               0.027418295297782325
#   validation error rate:         3.7299999999999973%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 989 of 1000 took 23.7995910645s
#   LR:                            3.35058974334e-07
#   training loss:                 0.06092613691858524
#   validation loss:               0.026470213148116473
#   validation error rate:         3.529999999999997%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 990 of 1000 took 23.67359519s
#   LR:                            3.31987135193e-07
#   training loss:                 0.06140284518516054
#   validation loss:               0.02637537165309292
#   validation error rate:         3.7299999999999964%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 991 of 1000 took 23.9826779366s
#   LR:                            3.28943458843e-07
#   training loss:                 0.061641019962833596
#   validation loss:               0.026351051175033932
#   validation error rate:         3.5499999999999967%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 992 of 1000 took 23.7218499184s
#   LR:                            3.25927687085e-07
#   training loss:                 0.061271292127430266
#   validation loss:               0.026980555483245242
#   validation error rate:         3.679999999999997%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 993 of 1000 took 23.7682440281s
#   LR:                            3.22939564089e-07
#   training loss:                 0.060226023093257273
#   validation loss:               0.02743882094050654
#   validation error rate:         3.749999999999997%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 994 of 1000 took 23.7147750854s
#   LR:                            3.19978836369e-07
#   training loss:                 0.061627823940112
#   validation loss:               0.026592508636039076
#   validation error rate:         3.6999999999999975%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 995 of 1000 took 23.8207747936s
#   LR:                            3.17045252764e-07
#   training loss:                 0.06099651324738662
#   validation loss:               0.02738836872473995
#   validation error rate:         3.8499999999999988%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 996 of 1000 took 23.8681869507s
#   LR:                            3.14138564415e-07
#   training loss:                 0.06049825194958299
#   validation loss:               0.027321901401520396
#   validation error rate:         3.8099999999999983%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 997 of 1000 took 24.051431179s
#   LR:                            3.11258524745e-07
#   training loss:                 0.06117107237171914
#   validation loss:               0.027740554764614882
#   validation error rate:         3.699999999999996%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 998 of 1000 took 23.9075651169s
#   LR:                            3.08404889438e-07
#   training loss:                 0.06116194428507064
#   validation loss:               0.02641106981059911
#   validation error rate:         3.6299999999999977%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 999 of 1000 took 23.8495349884s
#   LR:                            3.05577416416e-07
#   training loss:                 0.06182415341182204
#   validation loss:               0.027051896426228707
#   validation error rate:         3.8899999999999975%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%
# Epoch 1000 of 1000 took 23.8294289112s
#   LR:                            3.02775865823e-07
#   training loss:                 0.061444220121505196
#   validation loss:               0.02576634484393338
#   validation error rate:         3.599999999999996%
#   best epoch:                    965
#   best validation error rate:    3.4399999999999973%
#   test loss:                     0.02810769454178308
#   test error rate:               3.9099999999999966%

# %% [markdown]
# Are you done? Please backup the generated .npz file in your local computer so that we don't have to train the BNN again :)
#
# ## Step 5: Pack pickled weights and thresholds into its binary representation (OPTIONAL)
# This step should be run in your local machine, after transferring the .npz file.
# If you decide to run it here, transfer the generated
# ./BNN-PYNQ/bnn/src/training/sfcW1A1 directory to your local machine after executing the packing script.

# %%
#Step 5: Pack pickled weights and thresholds into its binary representation.
############################################################################

#Generate weights
# !python2 sfc_mnist-gen-weights.py
# Out:
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 6 (delta 5), reused 6 (delta 5), pack-reused 0
# Unpacking objects: 100% (6/6), done.
# From https://github.com/fcaspe/BNN-PYNQ
#    3b92a65..b09e5cb  master     -> origin/master
# Updating 3b92a65..b09e5cb
# Fast-forward
#  bnn/src/training/mnist_sfc.py | 2 +-
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %% [markdown]
# ## Done!
#
# By this time you should transfer the generated .npz file back to your local computer.
# If you ran Step 5, you don't need to pack the weights again.
# ### Transfer both the .npz file and sfcW1A1 directory to your local PC to proceed with HLS synthesis.
